# %%
#!pip install -U scikit-learn
#!pip install -U xgboost

# %%
import xgboost as xgb
import sklearn as skl
print(xgb.__version__, skl.__version__)
# Out:
# 1.4.2 0.24.2

# %% [markdown]
# # Main.py

# %%
from utils import Utils
import pandas as pd
import os

# %%
utils = Utils()

ramanList = utils.load_from_csv('in', clear=True)

# %%
os.listdir('in')
# Out:
# ['thumbNail.csv', 'vein.csv', 'earLobe.csv', 'innerArm.csv']

# %% [markdown]
# The order would be:
#
# *   innerArm: 3
# *   vein: 1
# *   thumbNail: 0
# *   earLobe: 2

# %%
innerArm = ramanList[3]  ## innerArm ###
vein = ramanList[1]      #### vein #####
thumbNail = ramanList[0] ## thumbNail ##
earLobe = ramanList[2]   ### earLobe ###

# %% [markdown]
# # No preprocessing

# %% [markdown]
# ## innerArm

# %% [markdown]
# ### AdaBoost

# %%
# %%time
from AdaBoost import ABC
abc_iA = ABC(innerArm, 'innerArm', rs=1)
# Out:
# Running AdaBoost for innerArm...
#    Looking for the best model for innerArm without preprocessing...
#    From innerArm: Best model: AdaBoostClassifier(learning_rate=0.001) | Best score: 0.3
# Metrics for innerArm with AdaBoost...
#               precision    recall  f1-score   support
#
#          0.0       0.40      1.00      0.57         2
#          1.0       1.00      0.40      0.57         5
#
#     accuracy                           0.57         7
#    macro avg       0.70      0.70      0.57         7
# weighted avg       0.83      0.57      0.57         7
#
# CPU times: user 29min 19s, sys: 14.8 s, total: 29min 34s
# Wall time: 30min 8s

# %% [markdown]
# ### Gradient Boosting

# %%
# %%time
from GradientBoosting import GBC
gbc_iA = GBC(innerArm, 'innerArm', rs=1)
# Out:
# Running Gradient Boosting for innerArm...
#    Looking for the best model for innerArm without preprocessing...
#    From innerArm: Best model: GradientBoostingClassifier(learning_rate=0.0001, loss='exponential',
#                            max_depth=7, max_features='log2', n_estimators=600) | Best score: 0.45
# Metrics for innerArm with GradientBoosting...
#               precision    recall  f1-score   support
#
#          0.0       0.29      1.00      0.44         2
#          1.0       0.00      0.00      0.00         5
#
#     accuracy                           0.29         7
#    macro avg       0.14      0.50      0.22         7
# weighted avg       0.08      0.29      0.13         7
#
# CPU times: user 1min 37s, sys: 410 ms, total: 1min 37s
# Wall time: 1min 38s

# %% [markdown]
# ### XGBoost

# %%
# %%time
from XGBoost import XGB
xgbc_iA = XGB(innerArm, 'innerArm', rs=1)
# Out:
# Ejecutando XGBoost para innerArm...
#    Looking for the best model for innerArm without preprocessing..
#    From innerArm: Best model: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.9, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.01, max_delta_step=0, max_depth=10,
#               min_child_weight=6, missing=nan, monotone_constraints='()',
#               n_estimators=400, n_jobs=4, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=0.27, scale_pos_weight=1, subsample=0.4,
#               tree_method='exact', validate_parameters=1, verbosity=0) | Best score: 0.45
# Metrics for innerArm with  XGBoost...
#               precision    recall  f1-score   support
#
#          0.0       0.29      1.00      0.44         2
#          1.0       0.00      0.00      0.00         5
#
# ...

# %% [markdown]
# ## vein

# %% [markdown]
# ### AdaBoost

# %%
# %%time
from AdaBoost import ABC
abc_v = ABC(vein, 'vein', rs=1)
# Out:
# Running AdaBoost for vein...
#    Looking for the best model for vein without preprocessing...
#    From vein: Best model: AdaBoostClassifier(learning_rate=0.001) | Best score: 0.55
# Metrics for vein with AdaBoost...
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         2
#          1.0       0.33      0.20      0.25         5
#
#     accuracy                           0.14         7
#    macro avg       0.17      0.10      0.12         7
# weighted avg       0.24      0.14      0.18         7
#
# CPU times: user 28min 49s, sys: 13.4 s, total: 29min 3s
# Wall time: 29min 26s

# %% [markdown]
# ### Gradient Boosting

# %%
# %%time
from GradientBoosting import GBC
gbc_v = GBC(vein, 'vein', rs=1)
# Out:
# Running Gradient Boosting for vein...
#    Looking for the best model for vein without preprocessing...
#    From vein: Best model: GradientBoostingClassifier(learning_rate=0.001, max_depth=4,
#                            max_features='sqrt', n_estimators=700) | Best score: 0.6
# Metrics for vein with GradientBoosting...
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         2
#          1.0       0.33      0.20      0.25         5
#
#     accuracy                           0.14         7
#    macro avg       0.17      0.10      0.12         7
# weighted avg       0.24      0.14      0.18         7
#
# CPU times: user 1min 20s, sys: 129 ms, total: 1min 20s
# Wall time: 1min 20s

# %% [markdown]
# ### XGBoost

# %%
# %%time
from XGBoost import XGB
xgbc_v = XGB(vein, 'vein', rs=1)
# Out:
# Ejecutando XGBoost para vein...
#    Looking for the best model for vein without preprocessing..
#    From vein: Best model: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.2, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.1, max_delta_step=0, max_depth=4,
#               min_child_weight=2, missing=nan, monotone_constraints='()',
#               n_estimators=400, n_jobs=4, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=0.92, scale_pos_weight=1, subsample=0.9,
#               tree_method='exact', validate_parameters=1, verbosity=0) | Best score: 0.6
# Metrics for vein with  XGBoost...
#               precision    recall  f1-score   support
#
#          0.0       0.29      1.00      0.44         2
#          1.0       0.00      0.00      0.00         5
#
# ...

# %% [markdown]
# ## thumbNail

# %% [markdown]
# ### AdaBoost

# %%
# %%time
from AdaBoost import ABC
abc_tN = ABC(thumbNail, 'thumbNail', rs=1)
# Out:
# Running AdaBoost for thumbNail...
#    Looking for the best model for thumbNail without preprocessing...
#    From thumbNail: Best model: AdaBoostClassifier(learning_rate=0.05, n_estimators=950) | Best score: 0.55
# Metrics for thumbNail with AdaBoost...
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         2
#          1.0       0.60      0.60      0.60         5
#
#     accuracy                           0.43         7
#    macro avg       0.30      0.30      0.30         7
# weighted avg       0.43      0.43      0.43         7
#
# CPU times: user 30min 6s, sys: 14.9 s, total: 30min 21s
# Wall time: 30min 49s

# %% [markdown]
# ### Gradient Boosting

# %%
# %%time
from GradientBoosting import GBC
gbc_tN = GBC(thumbNail, 'thumbNail', rs=1)
# Out:
# Running Gradient Boosting for thumbNail...
#    Looking for the best model for thumbNail without preprocessing...
#    From thumbNail: Best model: GradientBoostingClassifier(max_depth=7, max_features='sqrt', n_estimators=550) | Best score: 0.45
# Metrics for thumbNail with GradientBoosting...
#               precision    recall  f1-score   support
#
#          0.0       0.25      0.50      0.33         2
#          1.0       0.67      0.40      0.50         5
#
#     accuracy                           0.43         7
#    macro avg       0.46      0.45      0.42         7
# weighted avg       0.55      0.43      0.45         7
#
# CPU times: user 1min 54s, sys: 777 ms, total: 1min 55s
# Wall time: 1min 57s

# %% [markdown]
# ### XGBoost

# %%
# %%time
from XGBoost import XGB
xgbc_tN = XGB(thumbNail, 'thumbNail', rs=1)
# Out:
# Ejecutando XGBoost para thumbNail...
#    Looking for the best model for thumbNail without preprocessing..
#    From thumbNail: Best model: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.3, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.01, max_delta_step=0, max_depth=8,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=950, n_jobs=4, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=0.11, scale_pos_weight=1, subsample=0.1,
#               tree_method='exact', validate_parameters=1, verbosity=0) | Best score: 0.45
# Metrics for thumbNail with  XGBoost...
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         2
#          1.0       0.71      1.00      0.83         5
#
# ...

# %% [markdown]
# ## earLobe

# %% [markdown]
# ### AdaBoost

# %%
# %%time
from AdaBoost import ABC
abc_eL = ABC(earLobe, 'earLobe', rs=1)
# Out:
# Running AdaBoost for earLobe...
#    Looking for the best model for earLobe without preprocessing...
#    From earLobe: Best model: AdaBoostClassifier(learning_rate=0.001, n_estimators=600) | Best score: 0.7
# Metrics for earLobe with AdaBoost...
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67         2
#          1.0       1.00      0.60      0.75         5
#
#     accuracy                           0.71         7
#    macro avg       0.75      0.80      0.71         7
# weighted avg       0.86      0.71      0.73         7
#
# CPU times: user 28min 46s, sys: 10.4 s, total: 28min 56s
# Wall time: 29min 9s

# %% [markdown]
# ### Gradient Boosting

# %%
# %%time
from GradientBoosting import GBC
gbc_eL = GBC(earLobe, 'earLobe', rs=1)
# Out:
# Running Gradient Boosting for earLobe...
#    Looking for the best model for earLobe without preprocessing...
#    From earLobe: Best model: GradientBoostingClassifier(learning_rate=0.05, loss='exponential', max_depth=8,
#                            max_features='auto', n_estimators=400) | Best score: 0.6
# Metrics for earLobe with GradientBoosting...
#               precision    recall  f1-score   support
#
#          0.0       0.29      1.00      0.44         2
#          1.0       0.00      0.00      0.00         5
#
#     accuracy                           0.29         7
#    macro avg       0.14      0.50      0.22         7
# weighted avg       0.08      0.29      0.13         7
#
# CPU times: user 51.5 s, sys: 106 ms, total: 51.6 s
# Wall time: 51.6 s

# %% [markdown]
# ### XGBoost

# %%
# %%time
from XGBoost import XGB
xgbc_eL = XGB(earLobe, 'earLobe', rs=1)
# Out:
# Ejecutando XGBoost para earLobe...
#    Looking for the best model for earLobe without preprocessing..
#    From earLobe: Best model: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.5, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.05, max_delta_step=0, max_depth=7,
#               min_child_weight=3, missing=nan, monotone_constraints='()',
#               n_estimators=450, n_jobs=4, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=0.8, scale_pos_weight=1, subsample=0.9,
#               tree_method='exact', validate_parameters=1, verbosity=0) | Best score: 0.55
# Metrics for earLobe with  XGBoost...
#               precision    recall  f1-score   support
#
#          0.0       0.29      1.00      0.44         2
#          1.0       0.00      0.00      0.00         5
#
# ...

# %% [markdown]
# # With PCA preprocessing

# %% [markdown]
# ## innerArm

# %% [markdown]
# ### AdaBoost

# %%
# %%time
from AdaBoost import ABC
abc_iA_pca = ABC(innerArm, 'innerArm', rs=1, prePros=True, model=abc_iA.best_model, solver='pca')
# Out:
# Running AdaBoost for innerArm...
# Metrics for innerArm with preprocessing...
#    Calculating the best component and best score for PCA...
#    SCORE PCA: 0.7142857142857143 | n = 2
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.50      0.40         2
#          1.0       0.75      0.60      0.67         5
#
#     accuracy                           0.57         7
#    macro avg       0.54      0.55      0.53         7
# weighted avg       0.63      0.57      0.59         7
#
# CPU times: user 10.2 s, sys: 1.68 s, total: 11.9 s
# Wall time: 5.61 s

# %% [markdown]
# ### GradientBoosting

# %%
# %%time
from GradientBoosting import GBC
gbc_iA_pca = GBC(innerArm, 'innerArm', rs=1, prePros=True, model=gbc_iA.best_model, solver='pca')
# Out:
# Running Gradient Boosting for innerArm...
#    Calculating the best component and best score for PCA...
#    SCORE PCA: 0.2857142857142857 | n = 1
# Metrics for innerArm with preprocessing...
#               precision    recall  f1-score   support
#
#          0.0       0.29      1.00      0.44         2
#          1.0       0.00      0.00      0.00         5
#
#     accuracy                           0.29         7
#    macro avg       0.14      0.50      0.22         7
# weighted avg       0.08      0.29      0.13         7
#
# CPU times: user 11.3 s, sys: 882 ms, total: 12.2 s
# Wall time: 4.34 s

# %% [markdown]
# ### XGBoost

# %%
# %%time
from XGBoost import XGB
xgbc_iA_pca = XGB(innerArm, 'innerArm', rs=1, prePros=True, model=xgbc_iA.best_model, solver='pca')
# Out:
# Ejecutando XGBoost para innerArm...
#    Calculating the best component and best score for PCA...
#    SCORE PCA: 0.2857142857142857 | n = 1
# Metrics for innerArm with preprocessing...
#               precision    recall  f1-score   support
#
#          0.0       0.29      1.00      0.44         2
#          1.0       0.00      0.00      0.00         5
#
#     accuracy                           0.29         7
#    macro avg       0.14      0.50      0.22         7
# weighted avg       0.08      0.29      0.13         7
#
# CPU times: user 5.68 s, sys: 604 ms, total: 6.29 s
# Wall time: 1.68 s

# %% [markdown]
# ## vein

# %% [markdown]
# ### AdaBoost

# %%
# %%time
from AdaBoost import ABC
abc_v_pca = ABC(vein, 'vein', rs=1, prePros=True, model=abc_v.best_model, solver='pca')
# Out:
# Running AdaBoost for vein...
# Metrics for vein with preprocessing...
#    Calculating the best component and best score for PCA...
#    SCORE PCA: 0.14285714285714285 | n = 1
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         2
#          1.0       0.33      0.20      0.25         5
#
#     accuracy                           0.14         7
#    macro avg       0.17      0.10      0.12         7
# weighted avg       0.24      0.14      0.18         7
#
# CPU times: user 5.25 s, sys: 770 ms, total: 6.02 s
# Wall time: 1.9 s

# %% [markdown]
# ### Gradient Boosting

# %%
# %%time
from GradientBoosting import GBC
gbc_v_pca = GBC(vein, 'vein', rs=1, prePros=True, model=gbc_v.best_model, solver='pca')
# Out:
# Running Gradient Boosting for vein...
#    Calculating the best component and best score for PCA...
#    SCORE PCA: 0.2857142857142857 | n = 1
# Metrics for vein with preprocessing...
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         2
#          1.0       0.33      0.20      0.25         5
#
#     accuracy                           0.14         7
#    macro avg       0.17      0.10      0.12         7
# weighted avg       0.24      0.14      0.18         7
#
# CPU times: user 11.8 s, sys: 901 ms, total: 12.7 s
# Wall time: 4.68 s

# %% [markdown]
# ### XGBoost

# %%
# %%time
from XGBoost import XGB
xgbc_v_pca = XGB(vein, 'vein', rs=1, prePros=True, model=xgbc_v.best_model, solver='pca')
# Out:
# Ejecutando XGBoost para vein...
#    Calculating the best component and best score for PCA...
#    SCORE PCA: 0.2857142857142857 | n = 1
# Metrics for vein with preprocessing...
#               precision    recall  f1-score   support
#
#          0.0       0.29      1.00      0.44         2
#          1.0       0.00      0.00      0.00         5
#
#     accuracy                           0.29         7
#    macro avg       0.14      0.50      0.22         7
# weighted avg       0.08      0.29      0.13         7
#
# CPU times: user 5.68 s, sys: 609 ms, total: 6.29 s
# Wall time: 1.67 s

# %% [markdown]
# ## thumbNail

# %% [markdown]
# ### AdaBoost

# %%
# %%time
from AdaBoost import ABC
abc_tN_pca = ABC(thumbNail, 'thumbNail', rs=1, prePros=True, model=abc_tN.best_model, solver='pca')
# Out:
# Running AdaBoost for thumbNail...
# Metrics for thumbNail with preprocessing...
#    Calculating the best component and best score for PCA...
#    SCORE PCA: 0.7142857142857143 | n = 1
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         2
#          1.0       0.67      0.80      0.73         5
#
#     accuracy                           0.57         7
#    macro avg       0.33      0.40      0.36         7
# weighted avg       0.48      0.57      0.52         7
#
# CPU times: user 21.9 s, sys: 930 ms, total: 22.8 s
# Wall time: 15.1 s

# %% [markdown]
# ### Gradient Boosting

# %%
# %%time
from GradientBoosting import GBC
gbc_tN_pca = GBC(thumbNail, 'thumbNail', rs=1, prePros=True, model=gbc_tN.best_model, solver='pca')
# Out:
# Running Gradient Boosting for thumbNail...
#    Calculating the best component and best score for PCA...
#    SCORE PCA: 0.7142857142857143 | n = 1
# Metrics for thumbNail with preprocessing...
#               precision    recall  f1-score   support
#
#          0.0       0.25      0.50      0.33         2
#          1.0       0.67      0.40      0.50         5
#
#     accuracy                           0.43         7
#    macro avg       0.46      0.45      0.42         7
# weighted avg       0.55      0.43      0.45         7
#
# CPU times: user 10.8 s, sys: 886 ms, total: 11.7 s
# Wall time: 3.77 s

# %% [markdown]
# ### XGBoost

# %%
# %%time
from XGBoost import XGB
xgbc_tN_pca = XGB(thumbNail, 'thumbNail', rs=1, prePros=True, model=xgbc_tN.best_model, solver='pca')
# Out:
# Ejecutando XGBoost para thumbNail...
#    Calculating the best component and best score for PCA...
#    SCORE PCA: 0.7142857142857143 | n = 1
# Metrics for thumbNail with preprocessing...
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         2
#          1.0       0.71      1.00      0.83         5
#
#     accuracy                           0.71         7
#    macro avg       0.36      0.50      0.42         7
# weighted avg       0.51      0.71      0.60         7
#
# CPU times: user 8.59 s, sys: 743 ms, total: 9.33 s
# Wall time: 2.44 s

# %% [markdown]
# ## earLobe

# %% [markdown]
# ### AdaBoost

# %%
# %%time
from AdaBoost import ABC
abc_eL_pca = ABC(earLobe, 'earLobe', rs=1, prePros=True, model=abc_eL.best_model, solver='pca')
# Out:
# Running AdaBoost for earLobe...
# Metrics for earLobe with preprocessing...
#    Calculating the best component and best score for PCA...
#    SCORE PCA: 0.8571428571428571 | n = 12
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80         2
#          1.0       1.00      0.80      0.89         5
#
#     accuracy                           0.86         7
#    macro avg       0.83      0.90      0.84         7
# weighted avg       0.90      0.86      0.86         7
#
# CPU times: user 16.9 s, sys: 922 ms, total: 17.8 s
# Wall time: 9.83 s

# %% [markdown]
# ### Gradient Boosting

# %%
# %%time
from GradientBoosting import GBC
gbc_eL_pca = GBC(earLobe, 'earLobe', rs=1, prePros=True, model=gbc_eL.best_model, solver='pca')
# Out:
# Running Gradient Boosting for earLobe...
#    Calculating the best component and best score for PCA...
#    SCORE PCA: 0.8571428571428571 | n = 12
# Metrics for earLobe with preprocessing...
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80         2
#          1.0       1.00      0.80      0.89         5
#
#     accuracy                           0.86         7
#    macro avg       0.83      0.90      0.84         7
# weighted avg       0.90      0.86      0.86         7
#
# CPU times: user 9.56 s, sys: 886 ms, total: 10.4 s
# Wall time: 2.9 s

# %% [markdown]
# ### XGBoost

# %%
# %%time
from XGBoost import XGB
xgbc_eL_pca = XGB(earLobe, 'earLobe', rs=1, prePros=True, model=xgbc_eL.best_model, solver='pca')
# Out:
# Ejecutando XGBoost para earLobe...
#    Calculating the best component and best score for PCA...
#    SCORE PCA: 0.2857142857142857 | n = 1
# Metrics for earLobe with preprocessing...
#               precision    recall  f1-score   support
#
#          0.0       0.29      1.00      0.44         2
#          1.0       0.00      0.00      0.00         5
#
#     accuracy                           0.29         7
#    macro avg       0.14      0.50      0.22         7
# weighted avg       0.08      0.29      0.13         7
#
# CPU times: user 5.96 s, sys: 615 ms, total: 6.58 s
# Wall time: 1.74 s

# %% [markdown]
# # With LDA preprocessing

# %% [markdown]
# ## innerArm

# %% [markdown]
# ### AdaBoost

# %%
# %%time
from AdaBoost import ABC
abc_iA_lda = ABC(innerArm, 'innerArm', rs=1, prePros=True, model=abc_iA.best_model, solver='lda')
# Out:
# Running AdaBoost for innerArm...
# Metrics for innerArm with preprocessing...
#    Calculating best component and best score for LDA...
#    The maximum number of components allowed is 1
#    SCORE LDA: 0.14285714285714285
#               precision    recall  f1-score   support
#
#          0.0       0.17      0.50      0.25         2
#          1.0       0.00      0.00      0.00         5
#
#     accuracy                           0.14         7
#    macro avg       0.08      0.25      0.12         7
# weighted avg       0.05      0.14      0.07         7
#
# CPU times: user 981 ms, sys: 121 ms, total: 1.1 s
# Wall time: 521 ms

# %% [markdown]
# ### Gradient Boosting

# %%
# %%time
from GradientBoosting import GBC
gbc_iA_lda = GBC(innerArm, 'innerArm', rs=1, prePros=True, model=gbc_iA.best_model, solver='lda')
# Out:
# Running Gradient Boosting for innerArm...
#    Calculating best component and best score for LDA...
#    The maximum number of components allowed is 1
#    SCORE LDA: 0.2857142857142857
# Metrics for innerArm with preprocessing...
#               precision    recall  f1-score   support
#
#          0.0       0.29      1.00      0.44         2
#          1.0       0.00      0.00      0.00         5
#
#     accuracy                           0.29         7
#    macro avg       0.14      0.50      0.22         7
# weighted avg       0.08      0.29      0.13         7
#
# CPU times: user 1.16 s, sys: 97.5 ms, total: 1.26 s
# Wall time: 601 ms

# %% [markdown]
# ### XGBoost

# %%
# %%time
from XGBoost import XGB
xgbc_iA_lda = XGB(innerArm, 'innerArm', rs=1, prePros=True, model=xgbc_iA.best_model, solver='lda')
# Out:
# Ejecutando XGBoost para innerArm...
#    Calculating best component and best score for LDA...
#    The maximum number of components allowed is 1
#    SCORE LDA: 0.2857142857142857
# Metrics for innerArm with preprocessing...
#               precision    recall  f1-score   support
#
#          0.0       0.29      1.00      0.44         2
#          1.0       0.00      0.00      0.00         5
#
#     accuracy                           0.29         7
#    macro avg       0.14      0.50      0.22         7
# weighted avg       0.08      0.29      0.13         7
#
# CPU times: user 1.24 s, sys: 98.7 ms, total: 1.34 s
# Wall time: 425 ms

# %% [markdown]
# ## vein

# %% [markdown]
# ### AdaBoost

# %%
# %%time
from AdaBoost import ABC
abc_v_lda = ABC(vein, 'vein', rs=1, prePros=True, model=abc_v.best_model, solver='lda')
# Out:
# Running AdaBoost for vein...
# Metrics for vein with preprocessing...
#    Calculating best component and best score for LDA...
#    The maximum number of components allowed is 1
#    SCORE LDA: 0.2857142857142857
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         2
#          1.0       0.50      0.40      0.44         5
#
#     accuracy                           0.29         7
#    macro avg       0.25      0.20      0.22         7
# weighted avg       0.36      0.29      0.32         7
#
# CPU times: user 981 ms, sys: 99 ms, total: 1.08 s
# Wall time: 438 ms

# %% [markdown]
# ### Gradient Boosting

# %%
# %%time
from GradientBoosting import GBC
gbc_v_lda = GBC(vein, 'vein', rs=1, prePros=True, model=gbc_v.best_model, solver='lda')
# Out:
# Running Gradient Boosting for vein...
#    Calculating best component and best score for LDA...
#    The maximum number of components allowed is 1
#    SCORE LDA: 0.0
# Metrics for vein with preprocessing...
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       2.0
#          1.0       0.00      0.00      0.00       5.0
#
#     accuracy                           0.00       7.0
#    macro avg       0.00      0.00      0.00       7.0
# weighted avg       0.00      0.00      0.00       7.0
#
# CPU times: user 1.22 s, sys: 102 ms, total: 1.32 s
# Wall time: 660 ms

# %% [markdown]
# ### XGBoost

# %%
# %%time
from XGBoost import XGB
xgbc_v_lda = XGB(vein, 'vein', rs=1, prePros=True, model=xgbc_v.best_model, solver='lda')
# Out:
# Ejecutando XGBoost para vein...
#    Calculating best component and best score for LDA...
#    The maximum number of components allowed is 1
#    SCORE LDA: 0.2857142857142857
# Metrics for vein with preprocessing...
#               precision    recall  f1-score   support
#
#          0.0       0.29      1.00      0.44         2
#          1.0       0.00      0.00      0.00         5
#
#     accuracy                           0.29         7
#    macro avg       0.14      0.50      0.22         7
# weighted avg       0.08      0.29      0.13         7
#
# CPU times: user 1.25 s, sys: 104 ms, total: 1.36 s
# Wall time: 438 ms

# %% [markdown]
# ## thumbNail

# %% [markdown]
# ### AdaBoost

# %%
# %%time
from AdaBoost import ABC
abc_tN_lda = ABC(thumbNail, 'thumbNail', rs=1, prePros=True, model=abc_tN.best_model, solver='lda')
# Out:
# Running AdaBoost for thumbNail...
# Metrics for thumbNail with preprocessing...
#    Calculating best component and best score for LDA...
#    The maximum number of components allowed is 1
#    SCORE LDA: 0.14285714285714285
#               precision    recall  f1-score   support
#
#          0.0       0.17      0.50      0.25         2
#          1.0       0.00      0.00      0.00         5
#
#     accuracy                           0.14         7
#    macro avg       0.08      0.25      0.12         7
# weighted avg       0.05      0.14      0.07         7
#
# CPU times: user 2.12 s, sys: 115 ms, total: 2.23 s
# Wall time: 1.55 s

# %% [markdown]
# ### Gradient Boosting

# %%
# %%time
from GradientBoosting import GBC
gbc_tN_lda = GBC(thumbNail, 'thumbNail', rs=1, prePros=True, model=gbc_tN.best_model, solver='lda')
# Out:
# Running Gradient Boosting for thumbNail...
#    Calculating best component and best score for LDA...
#    The maximum number of components allowed is 1
#    SCORE LDA: 0.14285714285714285
# Metrics for thumbNail with preprocessing...
#               precision    recall  f1-score   support
#
#          0.0       0.17      0.50      0.25         2
#          1.0       0.00      0.00      0.00         5
#
#     accuracy                           0.14         7
#    macro avg       0.08      0.25      0.12         7
# weighted avg       0.05      0.14      0.07         7
#
# CPU times: user 1.14 s, sys: 125 ms, total: 1.26 s
# Wall time: 590 ms

# %% [markdown]
# ### XGBoost

# %%
# %%time
from XGBoost import XGB
xgbc_tN_lda = XGB(thumbNail, 'thumbNail', rs=1, prePros=True, model=xgbc_tN.best_model, solver='lda')
# Out:
# Ejecutando XGBoost para thumbNail...
#    Calculating best component and best score for LDA...
#    The maximum number of components allowed is 1
#    SCORE LDA: 0.7142857142857143
# Metrics for thumbNail with preprocessing...
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         2
#          1.0       0.71      1.00      0.83         5
#
#     accuracy                           0.71         7
#    macro avg       0.36      0.50      0.42         7
# weighted avg       0.51      0.71      0.60         7
#
# CPU times: user 1.49 s, sys: 112 ms, total: 1.6 s
# Wall time: 502 ms

# %% [markdown]
# ## earLobe

# %% [markdown]
# ### AdaBoost

# %%
# %%time
from AdaBoost import ABC
abc_el_lda = ABC(earLobe, 'earLobe', rs=1, prePros=True, model=abc_eL.best_model, solver='lda')
# Out:
# Running AdaBoost for earLobe...
# Metrics for earLobe with preprocessing...
#    Calculating best component and best score for LDA...
#    The maximum number of components allowed is 1
#    SCORE LDA: 0.42857142857142855
#               precision    recall  f1-score   support
#
#          0.0       0.33      1.00      0.50         2
#          1.0       1.00      0.20      0.33         5
#
#     accuracy                           0.43         7
#    macro avg       0.67      0.60      0.42         7
# weighted avg       0.81      0.43      0.38         7
#
# CPU times: user 1.74 s, sys: 109 ms, total: 1.85 s
# Wall time: 1.18 s

# %% [markdown]
# ### Gradient Boosting

# %%
# %%time
from GradientBoosting import GBC
gbc_eL_lda = GBC(earLobe, 'earLobe', rs=1, prePros=True, model=gbc_eL.best_model, solver='lda')
# Out:
# Running Gradient Boosting for earLobe...
#    Calculating best component and best score for LDA...
#    The maximum number of components allowed is 1
#    SCORE LDA: 0.5714285714285714
# Metrics for earLobe with preprocessing...
#               precision    recall  f1-score   support
#
#          0.0       0.40      1.00      0.57         2
#          1.0       1.00      0.40      0.57         5
#
#     accuracy                           0.57         7
#    macro avg       0.70      0.70      0.57         7
# weighted avg       0.83      0.57      0.57         7
#
# CPU times: user 1.08 s, sys: 116 ms, total: 1.19 s
# Wall time: 523 ms

# %% [markdown]
# ### XGBoost

# %%
# %%time
from XGBoost import XGB
xgbc_eL_lda = XGB(earLobe, 'earLobe', rs=1, prePros=True, model=xgbc_eL.best_model, solver='lda')
# Out:
# Ejecutando XGBoost para earLobe...
#    Calculating best component and best score for LDA...
#    The maximum number of components allowed is 1
#    SCORE LDA: 0.2857142857142857
# Metrics for earLobe with preprocessing...
#               precision    recall  f1-score   support
#
#          0.0       0.29      1.00      0.44         2
#          1.0       0.00      0.00      0.00         5
#
#     accuracy                           0.29         7
#    macro avg       0.14      0.50      0.22         7
# weighted avg       0.08      0.29      0.13         7
#
# CPU times: user 1.25 s, sys: 114 ms, total: 1.36 s
# Wall time: 431 ms
